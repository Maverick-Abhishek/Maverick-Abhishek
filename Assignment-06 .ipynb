# %% [markdown]
# # E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
# Be careful: There are two sheets (one is detailed) and second is encoded in the excel file. You may use any of them by extracting in separate excel sheet. The number of column(s) is more than 47. Read the column header carefully.
# Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.
# Need not to create machine learning models /but still if anybody comes with it that is welcome.

# %%
# Import the libraries.
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import numpy as np

# %%
library(readxl)

adata <- read_excel('C:\Users\win 7\Desktop\Datascience\Customer_retention_dataset---1-\Customer_retention_dataset\customer_retention_dataset.xlsx')
bdata <- read_excel('C:\Users\win 7\Desktop\Datascience\Customer_retention_dataset---1-\Customer_retention_dataset\customer_retention_dataset.xlsx', sheet = "codedshee
t")
# Out:
#   File "C:\Users\WIN7~1\AppData\Local\Temp/ipykernel_7064/1724169087.py", line 3
#     adata <- read_excel('C:\Users\win 7\Desktop\Datascience\Customer_retention_dataset---1-\Customer_retention_dataset\customer_retention_dataset.xlsx')
#                                                                                                                                                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
adata[,1:71] <- lapply(adata[,1:71], factor)

data <- data.frame(adata[,1:17], bdata[,18:47], adata[,48:71])

# %%
levels(data$X2.How.old.are.you.)[3] <- "41-50 years"

levels(data$X6.How.many.times.you.have.made.an.online.purchase.in.the.past.1.year.)[5] <- "41 times and above"

levels(data$X7.How.do.you.access.the.internet.while.shopping.on.line.)[2] <- "Mobile Internet"

# %%
library(ggplot2)

ggplot(data, aes(X2.How.old.are.you., 
                       fill = X1Gender.of.respondent))+
  geom_bar()+
  scale_x_discrete(limits=c("Less than 20 years",
                            "21-30 years", 
                            "31-40 years",
                            "41-50 years",
                            "51 years and above"))+
  labs(title="age and gender distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())

# %%
ggplot(data, aes(X3.Which.city.do.you.shop.online.from., 
                       fill = X4.What.is.the.Pin.Code.of.where.you.shop.online.from.))+
  geom_bar()+
  labs(title="city and pincode distribution", x ="", y = "")+
  theme(legend.position = "none", legend.key = element_blank())

# %%
ggplot(data, aes(X5.Since.How.Long.You.are.Shopping.Online.., fill = X6.How.many.times.you.have.made.an.online.purchase.in.the.past.1.year.))+
  geom_bar()+
  scale_x_discrete(limits = c("Less than 1 year",
                            "1-2 years",
                            "2-3 years",
                            "3-4 years",
                            "Above 4 years"))+
  labs(title="usage history and frequnency (last 1 year) distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_fill_discrete(limits = c("Less than 10 times", 
                                "11-20 times", 
                                "21-30 times",
                                "31-40 times",
                                "41 times and above"
                                ))

# %%
ggplot(data, aes(X7.How.do.you.access.the.internet.while.shopping.on.line., fill = X8.Which.device.do.you.use.to.access.the.online.shopping.))+
  geom_bar()+
  labs(title="connection and device distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())

# %%
ggplot(data, aes(X9.What.is.the.screen.size.of.your.mobile.device., fill = X10.What.is.the.operating.system..OS..of.your.device.))+
  geom_bar()+
  labs(title="screen size and OS distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())

# %%
ggplot(data, aes(X10.What.is.the.operating.system..OS..of.your.device., fill = X11.What.browser.do.you.run.on.your.device.to.access.the.website.))+
  geom_bar()+
  labs(title="OS and browser distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())

# %%
ggplot(data, aes(X12.Which.channel.did.you.follow.to.arrive.at.your.favorite.online.store.for.the.first.time., fill = X13.After.first.visit..how.do.you.reach.the.online.retail.store.))+
  geom_bar()+
  labs(title="first and regular channel distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())

# %%
ggplot(data, aes(X14.How.much.time.do.you.explore.the.e..retail.store.before.making.a.purchase.decision., fill = X15.What.is.your.preferred.payment.Option.))+
  geom_bar()+
  scale_x_discrete(limits=c("Less than 1 min",
                            "1-5 mins",
                            "6-10 mins",
                            "11-15 mins",
                            "more than 15 mins"))+
  labs(title="browsing time and payment method distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())

# %%
ggplot(data, aes(X16.How.frequently.do.you.abandon..selecting.an.items.and.leaving.without.making.payment..your.shopping.cart., fill = X17.Why.did.you.abandon.the..Bag....Shopping.Cart..))+
  geom_bar()+
  scale_x_discrete(limits=c("Never",
                            "Sometimes",
                            "Frequently",
                            "Very frequently"))+
  labs(title="cart abandon frequency and reason distribution", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())

# %%
p1 <- ggplot(data, aes(X18.The.content.on.the.website.must.be.easy.to.read.and.understand))+
  geom_boxplot()+
  labs(title="content.on.the.website.must.be.easy.to.read.and.understand", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p2 <- ggplot(data, aes(X19.Information.on.similar.product.to.the.one.highlighted..is.important.for.product.comparison))+
  geom_boxplot()+
  labs(title="Information.on.similar.product.to.the.one.highlighted..is.important", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))
  
p3 <- ggplot(data, aes(X20.Complete.information.on.listed.seller.and.product.being.offered.is.important.for.purchase.decision.))+
  geom_boxplot()+
  labs(title="Complete.information.on.listed.seller.and.product.being.offered.is.important", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p4 <- ggplot(data, aes(X21.All.relevant.information.on.listed.products.must.be.stated.clearly))+
  geom_boxplot()+
  labs(title="All.relevant.information.on.listed.products.must.be.stated.clearly", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p5 <- ggplot(data, aes(X22.Ease.of.navigation.in.website))+
  geom_boxplot()+
  labs(title="Ease.of.navigation.in.website", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p6 <- ggplot(data, aes(X23.Loading.and.processing.speed))+
  geom_boxplot()+
  labs(title="Loading.and.processing.speed", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p7 <- ggplot(data, aes(X24.User.friendly.Interface.of.the.website))+
  geom_boxplot()+
  labs(title="User.friendly.Interface.of.the.website", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p8 <- ggplot(data, aes(X25.Convenient.Payment.methods))+
  geom_boxplot()+
  labs(title="Convenient.Payment.methods", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p9 <- ggplot(data, aes(X26.Trust.that.the.online.retail.store.will.fulfill.its.part.of.the.transaction.at.the.stipulated.time))+
  geom_boxplot()+
  labs(title="Trust.that.the.online.retail.store.will.fulfill.its.part.of.the.transaction", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p10 <- ggplot(data, aes(X27.Empathy..readiness.to.assist.with.queries..towards.the.customers))+
  geom_boxplot()+
  labs(title="Empathy..readiness.to.assist.with.queries", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p11 <- ggplot(data, aes(X28.Being.able.to.guarantee.the.privacy.of.the.customer))+
  geom_boxplot()+
  labs(title="Being.able.to.guarantee", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p12 <- ggplot(data, aes(X29.Responsiveness..availability.of.several.communication.channels..email..online.rep..twitter..phone.etc..))+
  geom_boxplot()+
  labs(title="Responsiveness..availability", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p13 <- ggplot(data, aes(X30.Online.shopping.gives.monetary.benefit.and.discounts))+
  geom_boxplot()+
  labs(title="Online.shopping.gives.monetary.benefit.and.discounts", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p14 <- ggplot(data, aes(X31.Enjoyment.is.derived.from.shopping.online))+
  geom_boxplot()+
  labs(title="Enjoyment.is.derived", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p15 <- ggplot(data, aes(X32.Shopping.online.is.convenient.and.flexible))+
  geom_boxplot()+
  labs(title="Shopping.online.is.convenient.and.flexible", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p16 <- ggplot(data, aes(X33.Return.and.replacement.policy.of.the.e.tailer.is.important.for.purchase.decision))+
  geom_boxplot()+
  labs(title="Return.and.replacement.policy.of.the.e.tailer.is.important", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p17 <- ggplot(data, aes(X34.Gaining.access.to.loyalty.programs.is.a.benefit.of.shopping.online))+
  geom_boxplot()+
  labs(title="Gaining.access.to.loyalty.programs", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p18 <- ggplot(data, aes(X35.Displaying.quality.Information.on.the.website.improves.satisfaction.of.customers))+
  geom_boxplot()+
  labs(title="Displaying.quality.Information", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p19 <- ggplot(data, aes(X36.User.derive.satisfaction.while.shopping.on.a.good.quality.website.or.application))+
  geom_boxplot()+
  labs(title="User.derive.satisfaction", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p20 <- ggplot(data, aes(X37.Net.Benefit.derived.from.shopping.online.can.lead.to.users.satisfaction))+
  geom_boxplot()+
  labs(title="Net.Benefit.derived", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p21 <- ggplot(data, aes(X38.User.satisfaction.cannot.exist.without.trust))+
  geom_boxplot()+
  labs(title="User.satisfaction.cannot.exist.without.trust", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p22 <- ggplot(data, aes(X39.Offering.a.wide.variety.of.listed.product.in.several.category))+
  geom_boxplot()+
  labs(title="Offering.a.wide.variety.of.listed.product", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p23 <- ggplot(data, aes(X40.Provision.of.complete.and.relevant.product.information))+
  geom_boxplot()+
  labs(title="Provision.of.complete.and.relevant.product.information", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p24 <- ggplot(data, aes(X41.Monetary.savings))+
  geom_boxplot()+
  labs(title="Monetary.savings", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p25 <- ggplot(data, aes(X42.The.Convenience.of.patronizing.the.online.retailer))+
  geom_boxplot()+
  labs(title="The.Convenience.of.patronizing.the.online.retailer", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p26 <- ggplot(data, aes(X43.Shopping.on.the.website.gives.you.the.sense.of.adventure))+
  geom_boxplot()+
  labs(title="Shopping.on.the.website.gives.you.the.sense.of.adventure", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p27 <- ggplot(data, aes(X44.Shopping.on.your.preferred.e.tailer.enhances.your.social.status))+
  geom_boxplot()+
  labs(title="Shopping.on.your.preferred.e.tailer.enhances.your.social.status", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p28 <- ggplot(data, aes(X45.You.feel.gratification.shopping.on.your.favorite.e.tailer))+
  geom_boxplot()+
  labs(title="You.feel.gratification.shopping.on.your.favorite.e.tailer", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p29 <- ggplot(data, aes(X46.Shopping.on.the.website.helps.you.fulfill.certain.roles))+
  geom_boxplot()+
  labs(title="Shopping.on.the.website.helps.you.fulfill.certain.roles", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

p30 <- ggplot(data, aes(X47.Getting.value.for.money.spent))+
  geom_boxplot()+
  labs(title="Getting.value.for.money.spent", x ="", y = "")+
  theme(legend.position = "bottom", legend.title = element_blank())+
  scale_x_discrete(limits=c("1",
                            "2",
                            "3",
                            "4",
                            "5"))

gridExtra::grid.arrange(p1,p2,p3,p4,p5,p6, nrow = 6)
gridExtra::grid.arrange(p7,p8,p9,p10,p11,p12, nrow = 6)
gridExtra::grid.arrange(p13,p14,p15,p16,p17,p18, nrow = 6)
gridExtra::grid.arrange(p19,p20,p21,p22,p23,p24, nrow = 6)
gridExtra::grid.arrange(p25,p26,p27,p28,p29,p30, nrow = 6)

# %%
library ("stringr")

unique(unlist(data[,48:71]))

website <- c('Amazon','Flipkart','Myntra','Snapdeal','Paytm')

count   <- c(sum(str_count(data$From.the.following..tick.any..or.all..of.the.online.retailers.you.have.shopped.from., pattern = 'Amazon')),
             sum(str_count(data$From.the.following..tick.any..or.all..of.the.online.retailers.you.have.shopped.from., pattern = 'Flipkart')),
             sum(str_count(data$From.the.following..tick.any..or.all..of.the.online.retailers.you.have.shopped.from., pattern = 'Myntra')),
             sum(str_count(data$From.the.following..tick.any..or.all..of.the.online.retailers.you.have.shopped.from., pattern = 'Snapdeal')),
             sum(str_count(data$From.the.following..tick.any..or.all..of.the.online.retailers.you.have.shopped.from., pattern = 'Paytm')))

x48 <- data.frame(website, count)

ggplot(data = x48, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="past popularity", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Easy.to.use.website.or.application, pattern = 'Amazon')),
             sum(str_count(data$Easy.to.use.website.or.application, pattern = 'Flipkart')),
             sum(str_count(data$Easy.to.use.website.or.application, pattern = 'Myntra')),
             sum(str_count(data$Easy.to.use.website.or.application, pattern = 'Snapdeal')),
             sum(str_count(data$Easy.to.use.website.or.application, pattern = 'Paytm')))

x49 <- data.frame(website, count)

ggplot(data = x49, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="ease of use", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Visual.appealing.web.page.layout, pattern = 'Amazon')),
             sum(str_count(data$Visual.appealing.web.page.layout, pattern = 'Flipkart')),
             sum(str_count(data$Visual.appealing.web.page.layout, pattern = 'Myntra')),
             sum(str_count(data$Visual.appealing.web.page.layout, pattern = 'Snapdeal')),
             sum(str_count(data$Visual.appealing.web.page.layout, pattern = 'Paytm')))

x50 <- data.frame(website, count)

ggplot(data = x50, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="visual appeal", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Wild.variety.of.product.on.offer, pattern = 'Amazon')),
             sum(str_count(data$Wild.variety.of.product.on.offer, pattern = 'Flipkart')),
             sum(str_count(data$Wild.variety.of.product.on.offer, pattern = 'Myntra')),
             sum(str_count(data$Wild.variety.of.product.on.offer, pattern = 'Snapdeal')),
             sum(str_count(data$Wild.variety.of.product.on.offer, pattern = 'Paytm')))

x51 <- data.frame(website, count)

ggplot(data = x51, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="variety", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Complete..relevant.description.information.of.products, pattern = 'Amazon')),
             sum(str_count(data$Complete..relevant.description.information.of.products, pattern = 'Flipkart')),
             sum(str_count(data$Complete..relevant.description.information.of.products, pattern = 'Myntra')),
             sum(str_count(data$Complete..relevant.description.information.of.products, pattern = 'Snapdeal')),
             sum(str_count(data$Complete..relevant.description.information.of.products, pattern = 'Paytm')))

x52 <- data.frame(website, count)

ggplot(data = x52, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="description", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Fast.loading.website.speed.of.website.and.application, pattern = 'Amazon')),
             sum(str_count(data$Fast.loading.website.speed.of.website.and.application, pattern = 'Flipkart')),
             sum(str_count(data$Fast.loading.website.speed.of.website.and.application, pattern = 'Myntra')),
             sum(str_count(data$Fast.loading.website.speed.of.website.and.application, pattern = 'Snapdeal')),
             sum(str_count(data$Fast.loading.website.speed.of.website.and.application, pattern = 'Paytm')))

x53 <- data.frame(website, count)

ggplot(data = x53, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="speed", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Reliability.of.the.website.or.application, pattern = 'Amazon')),
             sum(str_count(data$Reliability.of.the.website.or.application, pattern = 'Flipkart')),
             sum(str_count(data$Reliability.of.the.website.or.application, pattern = 'Myntra')),
             sum(str_count(data$Reliability.of.the.website.or.application, pattern = 'Snapdeal')),
             sum(str_count(data$Reliability.of.the.website.or.application, pattern = 'Paytm')))

x54 <- data.frame(website, count)

ggplot(data = x54, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="reliability", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Quickness.to.complete.purchase, pattern = 'Amazon')),
             sum(str_count(data$Quickness.to.complete.purchase, pattern = 'Flipkart')),
             sum(str_count(data$Quickness.to.complete.purchase, pattern = 'Myntra')),
             sum(str_count(data$Quickness.to.complete.purchase, pattern = 'Snapdeal')),
             sum(str_count(data$Quickness.to.complete.purchase, pattern = 'Paytm')))

x55 <- data.frame(website, count)

ggplot(data = x55, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="purchase speed", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Availability.of.several.payment.options, pattern = 'Amazon')),
             sum(str_count(data$Availability.of.several.payment.options, pattern = 'Flipkart')),
             sum(str_count(data$Availability.of.several.payment.options, pattern = 'Myntra')),
             sum(str_count(data$Availability.of.several.payment.options, pattern = 'Snapdeal')),
             sum(str_count(data$Availability.of.several.payment.options, pattern = 'Paytm')))

x56 <- data.frame(website, count)

ggplot(data = x56, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="payment options", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Speedy.order.delivery, pattern = 'Amazon')),
             sum(str_count(data$Speedy.order.delivery, pattern = 'Flipkart')),
             sum(str_count(data$Speedy.order.delivery, pattern = 'Myntra')),
             sum(str_count(data$Speedy.order.delivery, pattern = 'Snapdeal')),
             sum(str_count(data$Speedy.order.delivery, pattern = 'Paytm')))

x57 <- data.frame(website, count)

ggplot(data = x57, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="delivery speed", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Privacy.of.customers..information, pattern = 'Amazon')),
             sum(str_count(data$Privacy.of.customers..information, pattern = 'Flipkart')),
             sum(str_count(data$Privacy.of.customers..information, pattern = 'Myntra')),
             sum(str_count(data$Privacy.of.customers..information, pattern = 'Snapdeal')),
             sum(str_count(data$Privacy.of.customers..information, pattern = 'Paytm')))

x58 <- data.frame(website, count)

ggplot(data = x58, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="privacy", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Security.of.customer.financial.information, pattern = 'Amazon')),
             sum(str_count(data$Security.of.customer.financial.information, pattern = 'Flipkart')),
             sum(str_count(data$Security.of.customer.financial.information, pattern = 'Myntra')),
             sum(str_count(data$Security.of.customer.financial.information, pattern = 'Snapdeal')),
             sum(str_count(data$Security.of.customer.financial.information, pattern = 'Paytm')))

x59 <- data.frame(website, count)

ggplot(data = x59, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="security", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Perceived.Trustworthiness, pattern = 'Amazon')),
             sum(str_count(data$Perceived.Trustworthiness, pattern = 'Flipkart')),
             sum(str_count(data$Perceived.Trustworthiness, pattern = 'Myntra')),
             sum(str_count(data$Perceived.Trustworthiness, pattern = 'Snapdeal')),
             sum(str_count(data$Perceived.Trustworthiness, pattern = 'Paytm')))

x60 <- data.frame(website, count)

ggplot(data = x60, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="Trustworthiness", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Presence.of.online.assistance.through.multi.channel, pattern = 'Amazon')),
             sum(str_count(data$Presence.of.online.assistance.through.multi.channel, pattern = 'Flipkart')),
             sum(str_count(data$Presence.of.online.assistance.through.multi.channel, pattern = 'Myntra')),
             sum(str_count(data$Presence.of.online.assistance.through.multi.channel, pattern = 'Snapdeal')),
             sum(str_count(data$Presence.of.online.assistance.through.multi.channel, pattern = 'Paytm')))

x61 <- data.frame(website, count)

ggplot(data = x61, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="assistance", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Longer.time.to.get.logged.in..promotion..sales.period., pattern = 'Amazon')),
             sum(str_count(data$Longer.time.to.get.logged.in..promotion..sales.period., pattern = 'Flipkart')),
             sum(str_count(data$Longer.time.to.get.logged.in..promotion..sales.period., pattern = 'Myntra')),
             sum(str_count(data$Longer.time.to.get.logged.in..promotion..sales.period., pattern = 'Snapdeal')),
             sum(str_count(data$Longer.time.to.get.logged.in..promotion..sales.period., pattern = 'Paytm')))

x62 <- data.frame(website, count)

ggplot(data = x62, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="login time during sales", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Longer.time.in.displaying.graphics.and.photos..promotion..sales.period., pattern = 'Amazon')),
             sum(str_count(data$Longer.time.in.displaying.graphics.and.photos..promotion..sales.period., pattern = 'Flipkart')),
             sum(str_count(data$Longer.time.in.displaying.graphics.and.photos..promotion..sales.period., pattern = 'Myntra')),
             sum(str_count(data$Longer.time.in.displaying.graphics.and.photos..promotion..sales.period., pattern = 'Snapdeal')),
             sum(str_count(data$Longer.time.in.displaying.graphics.and.photos..promotion..sales.period., pattern = 'Paytm')))

x63 <- data.frame(website, count)

ggplot(data = x63, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="graphic loading time during sales", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Late.declaration.of.price..promotion..sales.period., pattern = 'Amazon')),
             sum(str_count(data$Late.declaration.of.price..promotion..sales.period., pattern = 'Flipkart')),
             sum(str_count(data$Late.declaration.of.price..promotion..sales.period., pattern = 'Myntra')),
             sum(str_count(data$Late.declaration.of.price..promotion..sales.period., pattern = 'Snapdeal')),
             sum(str_count(data$Late.declaration.of.price..promotion..sales.period., pattern = 'Paytm')))

x64 <- data.frame(website, count)

ggplot(data = x64, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="late declaration", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Longer.page.loading.time..promotion..sales.period., pattern = 'Amazon')),
             sum(str_count(data$Longer.page.loading.time..promotion..sales.period., pattern = 'Flipkart')),
             sum(str_count(data$Longer.page.loading.time..promotion..sales.period., pattern = 'Myntra')),
             sum(str_count(data$Longer.page.loading.time..promotion..sales.period., pattern = 'Snapdeal')),
             sum(str_count(data$Longer.page.loading.time..promotion..sales.period., pattern = 'Paytm')))

x65 <- data.frame(website, count)

ggplot(data = x65, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="loading time", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Limited.mode.of.payment.on.most.products..promotion..sales.period., pattern = 'Amazon')),
             sum(str_count(data$Limited.mode.of.payment.on.most.products..promotion..sales.period., pattern = 'Flipkart')),
             sum(str_count(data$Limited.mode.of.payment.on.most.products..promotion..sales.period., pattern = 'Myntra')),
             sum(str_count(data$Limited.mode.of.payment.on.most.products..promotion..sales.period., pattern = 'Snapdeal')),
             sum(str_count(data$Limited.mode.of.payment.on.most.products..promotion..sales.period., pattern = 'Paytm')))

x66 <- data.frame(website, count)

ggplot(data = x66, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="limited payment mode for sales", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Longer.delivery.period, pattern = 'Amazon')),
             sum(str_count(data$Longer.delivery.period, pattern = 'Flipkart')),
             sum(str_count(data$Longer.delivery.period, pattern = 'Myntra')),
             sum(str_count(data$Longer.delivery.period, pattern = 'Snapdeal')),
             sum(str_count(data$Longer.delivery.period, pattern = 'Paytm')))

x67 <- data.frame(website, count)

ggplot(data = x67, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="longer delivery period", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Change.in.website.Application.design, pattern = 'Amazon')),
             sum(str_count(data$Change.in.website.Application.design, pattern = 'Flipkart')),
             sum(str_count(data$Change.in.website.Application.design, pattern = 'Myntra')),
             sum(str_count(data$Change.in.website.Application.design, pattern = 'Snapdeal')),
             sum(str_count(data$Change.in.website.Application.design, pattern = 'Paytm')))

x68 <- data.frame(website, count)

ggplot(data = x68, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="change in web design", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Frequent.disruption.when.moving.from.one.page.to.another, pattern = 'Amazon')),
             sum(str_count(data$Frequent.disruption.when.moving.from.one.page.to.another, pattern = 'Flipkart')),
             sum(str_count(data$Frequent.disruption.when.moving.from.one.page.to.another, pattern = 'Myntra')),
             sum(str_count(data$Frequent.disruption.when.moving.from.one.page.to.another, pattern = 'Snapdeal')),
             sum(str_count(data$Frequent.disruption.when.moving.from.one.page.to.another, pattern = 'Paytm')))

x69 <- data.frame(website, count)

ggplot(data = x69, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="frequent disruptions", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Website.is.as.efficient.as.before, pattern = 'Amazon')),
             sum(str_count(data$Website.is.as.efficient.as.before, pattern = 'Flipkart')),
             sum(str_count(data$Website.is.as.efficient.as.before, pattern = 'Myntra')),
             sum(str_count(data$Website.is.as.efficient.as.before, pattern = 'Snapdeal')),
             sum(str_count(data$Website.is.as.efficient.as.before, pattern = 'Paytm')))

x70 <- data.frame(website, count)

ggplot(data = x70, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="efficient as before", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

count   <- c(sum(str_count(data$Which.of.the.Indian.online.retailer.would.you.recommend.to.a.friend., pattern = 'Amazon')),
             sum(str_count(data$Which.of.the.Indian.online.retailer.would.you.recommend.to.a.friend., pattern = 'Flipkart')),
             sum(str_count(data$Which.of.the.Indian.online.retailer.would.you.recommend.to.a.friend., pattern = 'Myntra')),
             sum(str_count(data$Which.of.the.Indian.online.retailer.would.you.recommend.to.a.friend., pattern = 'Snapdeal')),
             sum(str_count(data$Which.of.the.Indian.online.retailer.would.you.recommend.to.a.friend., pattern = 'Paytm')))

x71 <- data.frame(website, count)

ggplot(data = x71, aes(x = website, y = count, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="recommendation", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

# %%
score <- data.frame(website, 
                      x48$count+
                      x49$count+
                      x50$count+
                      x51$count+
                      x52$count+
                      x53$count+
                      x54$count+
                      x55$count+
                      x56$count+
                      x57$count+
                      x58$count+
                      x59$count+
                      x60$count+
                      x61$count-
                      x62$count-
                      x63$count-
                      x64$count-
                      x65$count-
                      x66$count-
                      x67$count+
                      x68$count+
                      x69$count+
                      x70$count+
                      x71$count)

colnames(score)[2] <- "score"

ggplot(data = score, aes(x = website, y = score, fill = website)) + 
  geom_bar(stat="identity")+
  labs(title="score", x ="", y = "")+
  theme(legend.position = "none", legend.title = element_blank())

ndata <- scale(data[,18:47])

library(psych)

pairs.panels(ndata)

library(factoextra)

fviz_nbclust(ndata, kmeans, method = "wss")

fviz_nbclust(ndata, kmeans, method = "silhouette")

fviz_nbclust(ndata, kmeans, method = "gap_stat")

library(cluster)

set.seed(123)
cluster <- kmeans(ndata,5)
fviz_cluster( cluster, data = ndata, axes = c(1,2))
cluster$centers
cluster$size

clusplot(ndata, cluster$cluster, color = T, shade = T, labels = 2, lines = 0)

library(FactoMineR)

res.pca <- PCA(ndata, graph = TRUE)
fviz_eig(res.pca, addlabels = TRUE)

fviz_pca_var(res.pca, col.var = "cos2", 
             repel = TRUE, alpha.var = "contrib",  
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"))

fviz_pca_ind(res.pca, col.ind = "cos2", labels = FALSE,
             repel = FALSE, pointsize = "contrib",  
             gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"))

fviz_contrib(res.pca, choice = "var", axes = 1:2)
fviz_cos2(res.pca, choice = "var", axes = 1:2)
fviz_contrib(res.pca, choice = "ind", axes = 1:2)
fviz_cos2(res.pca, choice = "ind", axes = 1:2)

fviz_pca_biplot(res.pca,
                col.ind = "cos2",
                col.var = "contrib", 
                circle = TRUE,
                pointsize = "contrib", 
                alpha.var = "contrib",
                gradient.cols = c("#00AFBB", "#E7B800", "#FC4E07"),
                groups = cluster$cluster,
                addEllipses = TRUE,
                ellipse.type = "confidence")
